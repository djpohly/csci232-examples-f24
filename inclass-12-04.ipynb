# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
birds = pd.read_csv("birds_north_american.csv")
volcanos = pd.read_csv("volcanos.csv", encoding='ISO-8859-1')
world = pd.read_csv("population_by_country_2020.csv")

# %%
birds
# Out:
#                               RefugeName OnOffRefuge  PRIMR  Year  StateNum  \
# 0         Camas National Wildlife Refuge         off      0  1997        33
# 1         Camas National Wildlife Refuge         off      0  1997        33
# 2         Camas National Wildlife Refuge         off      0  1997        33
# 3         Camas National Wildlife Refuge         off      0  1997        33
# 4         Camas National Wildlife Refuge         off      0  1997        33
# ...                                  ...         ...    ...   ...       ...
# 12846  Umatilla National Wildlife Refuge          on      0  1998        69
# 12847  Umatilla National Wildlife Refuge          on      0  1998        69
# 12848  Umatilla National Wildlife Refuge          on      0  1998        69
# 12849  Umatilla National Wildlife Refuge          on      0  1998        69
# 12850  Umatilla National Wildlife Refuge          on      0  1998        69
#
# ...

# %%
birds.columns
# Out:
# Index(['RefugeName', 'OnOffRefuge', 'PRIMR', 'Year', 'StateNum', 'Route',
#        'RouteName', 'ScientificName', 'AOU', 'GenusName', 'SpeciesName',
#        'CommonName', 'Active', 'Latitude', 'Longitude', 'Stratum', 'BCR'],
#       dtype='object')

# %%
birds["GenusName"][:20]
# Out:
# 0        Leucophaeus
# 1               Anas
# 2            Spatula
# 3             Aythya
# 4         Charadrius
# 5            Columba
# 6            Zenaida
# 7             Circus
# 8              Buteo
# 9              Buteo
# 10        Chordeiles
# 11          Tyrannus
# 12          Tyrannus
# 13        Eremophila
# 14              Pica
# 15            Corvus
# 16           Sturnus
# 17         Molothrus
# 18    Xanthocephalus
# 19          Agelaius
# Name: GenusName, dtype: object

# %%
genera = birds["GenusName"].unique()
genera
# Out:
# array(['Leucophaeus', 'Anas', 'Spatula', 'Aythya', 'Charadrius',
#        'Columba', 'Zenaida', 'Circus', 'Buteo', 'Chordeiles', 'Tyrannus',
#        'Eremophila', 'Pica', 'Corvus', 'Sturnus', 'Molothrus',
#        'Xanthocephalus', 'Agelaius', 'Sturnella', 'Icterus', 'Euphagus',
#        'Haemorhous', 'Pooecetes', 'Passerculus', 'Petrochelidon',
#        'Hirundo', 'Stelgidopteryx', 'Setophaga', 'Geothlypis', 'Passer',
#        'Troglodytes', 'Sitta', 'Turdus', 'Larus', 'Mareca', 'Plegadis',
#        'Fulica', 'Phalaropus', 'Recurvirostra', 'Tringa', 'Numenius',
#        'Phasianus', 'Aquila', 'Falco', 'Melospiza', 'Passerina',
#        'Porzana', 'Cathartes', 'Colaptes', 'Spizella', 'Tachycineta',
#        'Dryobates', 'Empidonax', 'Spinus', 'Zonotrichia', 'Piranga',
#        'Antigone', 'Gallinago', 'Centrocercus', 'Dumetella', 'Asio',
#        'Contopus', 'Lanius', 'Oreoscoptes', 'Sialia', 'Ardea',
#        'Nycticorax', 'Actitis', 'Athene', 'Riparia', 'Chondestes',
# ...

# %%
birds["GenusName"].value_counts()
# Out:
# GenusName
# Buteo          332
# Corvus         315
# Tyrannus       260
# Agelaius       243
# Zenaida        240
#               ...
# Picoides         2
# Butorides        2
# Dendragapus      1
# Cinclus          1
# Tyto             1
# Name: count, Length: 154, dtype: int64

# %%
volcanos
# Out:
#         Number     Volcano Name        Country         Region  Latitude  \
# 0     0803-001              Abu          Japan   Honshu-Japan    34.500
# 1     1505-096       Acamarachi          Chile        Chile-N   -23.300
# 2     1402-08=       Acatenango      Guatemala      Guatemala    14.501
# 3     0103-004  Acigol-Nevsehir         Turkey         Turkey    38.570
# 4     1201-04-            Adams  United States  US-Washington    46.206
# ...        ...              ...            ...            ...       ...
# 1566  1000-12=      Zhupanovsky         Russia      Kamchatka    53.590
# 1567  1000-242           Zimina         Russia      Kamchatka    55.862
# 1568  0201-02=    Zubair, Jebel          Yemen        Red Sea    15.050
# 1569  0201-021            Zukur          Yemen        Red Sea    14.020
# 1570  1210-02-     Zuni-Bandera  United States  US-New Mexico    34.800
#
#       Longitude    Elev              Type            Status Last Known
# ...

# %%
volcanos.columns
# Out:
# Index(['Number', 'Volcano Name', 'Country', 'Region', 'Latitude', 'Longitude',
#        'Elev', 'Type', 'Status', 'Last Known'],
#       dtype='object')

# %%
world
# Out:
#     Country (or dependency)  Population (2020) Yearly Change  Net Change  \
# 0                     China         1440297825        0.39 %     5540090
# 1                     India         1382345085        0.99 %    13586631
# 2             United States          331341050        0.59 %     1937734
# 3                 Indonesia          274021604        1.07 %     2898047
# 4                  Pakistan          221612785        2.00 %     4327022
# ..                      ...                ...           ...         ...
# 230              Montserrat               4993        0.06 %           3
# 231        Falkland Islands               3497        3.05 %         103
# 232                    Niue               1628        0.68 %          11
# 233                 Tokelau               1360        1.27 %          17
# 234                Holy See                801        0.25 %           2
#
#      Density (P/Km2)  Land Area (Km2)  Migrants (net) Fert. Rate Med. Age  \
# ...

# %%
world.columns
# Out:
# Index(['Country (or dependency)', 'Population (2020)', 'Yearly Change',
#        'Net Change', 'Density (P/Km2)', 'Land Area (Km2)', 'Migrants (net)',
#        'Fert. Rate', 'Med. Age', 'Urban Pop %', 'World Share'],
#       dtype='object')

# %%
world.set_index("Country (or dependency)", inplace=True)
world
# Out:
#                          Population (2020) Yearly Change  Net Change  \
# Country (or dependency)
# China                           1440297825        0.39 %     5540090
# India                           1382345085        0.99 %    13586631
# United States                    331341050        0.59 %     1937734
# Indonesia                        274021604        1.07 %     2898047
# Pakistan                         221612785        2.00 %     4327022
# ...                                    ...           ...         ...
# Montserrat                            4993        0.06 %           3
# Falkland Islands                      3497        3.05 %         103
# Niue                                  1628        0.68 %          11
# Tokelau                               1360        1.27 %          17
# Holy See                               801        0.25 %           2
#
#                          Density (P/Km2)  Land Area (Km2)  Migrants (net)  \
# Country (or dependency)
# ...

# %%
volcanos.columns
# Out:
# Index(['Number', 'Volcano Name', 'Country', 'Region', 'Latitude', 'Longitude',
#        'Elev', 'Type', 'Status', 'Last Known'],
#       dtype='object')

# %%
volcanos.iloc[:5]
# Out:
#      Number     Volcano Name        Country         Region  Latitude  \
# 0  0803-001              Abu          Japan   Honshu-Japan    34.500
# 1  1505-096       Acamarachi          Chile        Chile-N   -23.300
# 2  1402-08=       Acatenango      Guatemala      Guatemala    14.501
# 3  0103-004  Acigol-Nevsehir         Turkey         Turkey    38.570
# 4  1201-04-            Adams  United States  US-Washington    46.206
#
#    Longitude    Elev            Type            Status Last Known
# 0    131.600   571.0  Shield volcano          Holocene    Unknown
# 1    -67.620  6046.0   Stratovolcano          Holocene    Unknown
# 2    -90.876  3976.0   Stratovolcano        Historical         D1
# 3     34.520  1689.0            Maar          Holocene          U
# 4   -121.490  3742.0   Stratovolcano  Tephrochronology         D6

# %%
volcanos["Country"].iloc[:20]
# Out:
# 0             Japan
# 1             Chile
# 2         Guatemala
# 3            Turkey
# 4     United States
# 5             Japan
# 6          Ethiopia
# 7          Ethiopia
# 8           Armenia
# 9     United States
# 10        Guatemala
# 11         Portugal
# 12            Chile
# 13        Indonesia
# 14    United States
# 15           Russia
# 16           Russia
# 17            Japan
# 18            Japan
# 19           Russia
# Name: Country, dtype: object

# %%
lonv = []
for country in world.index:
    if country not in volcanos["Country"].values:
        lonv.append(country)
lonv
# Out:
# ['Pakistan',
#  'Brazil',
#  'Bangladesh',
#  'Egypt',
#  'DR Congo',
#  'Thailand',
#  'Ukraine',
#  'Iraq',
#  'Poland',
#  'Morocco',
#  'Uzbekistan',
#  'Angola',
#  'Mozambique',
#  'Ghana',
#  'Nepal',
#  'Venezuela',
#  "Côte d'Ivoire",
#  'Niger',
#  'Sri Lanka',
#  'Burkina Faso',
#  'Romania',
#  'Malawi',
#  'Kazakhstan',
#  'Zambia',
#  'Senegal',
#  'Cambodia',
#  'Somalia',
#  'Zimbabwe',
#  'Guinea',
#  'Benin',
#  'Burundi',
#  'Tunisia',
#  'Belgium',
#  'Haiti',
#  'Cuba',
#  'South Sudan',
#  'Dominican Republic',
#  'Czech Republic (Czechia)',
#  'Jordan',
#  'Azerbaijan',
#  'United Arab Emirates',
#  'Hungary',
#  'Tajikistan',
#  'Belarus',
#  'Austria',
#  'Serbia',
#  'Israel',
#  'Switzerland',
#  'Togo',
#  'Sierra Leone',
#  'Hong Kong',
#  'Laos',
#  'Paraguay',
#  'Bulgaria',
#  'Lebanon',
#  'Kyrgyzstan',
#  'Turkmenistan',
#  'Singapore',
#  'Denmark',
#  'Finland',
#  'Congo',
#  'Slovakia',
#  'Norway',
#  'Oman',
#  'State of Palestine',
# ...

# %%
len(lonv)
# Out:
# 156

# %%
'Armenia' in lonv
# Out:
# False

# %%
volcanos["Country"])
# Out:
# ['Japan',
#  'Chile',
#  'Guatemala',
#  'Turkey',
#  'United States',
#  'Japan',
#  'Ethiopia',
#  'Ethiopia',
#  'Armenia',
#  'United States',
#  'Guatemala',
#  'Portugal',
#  'Chile',
#  'Indonesia',
#  'United States',
#  'Russia',
#  'Russia',
#  'Japan',
#  'Japan',
#  'Russia',
#  'Japan',
#  'Japan',
#  'Japan',
#  'Japan',
#  'United States',
#  'Russia',
#  'United States',
#  'Ethiopia',
#  'Italy',
#  'Ecuador',
#  'Ethiopia',
#  'Eritrea',
#  'Canada',
#  'Guatemala',
#  'Russia',
#  'Russia',
#  'Ethiopia',
#  'Ethiopia',
#  'United States',
#  'Indonesia',
#  'Philippines',
#  'Indonesia',
#  'Papua New Guinea',
#  'United States',
#  'Madagascar',
#  'Vanuatu',
#  'Philippines',
#  'Indian Ocean',
#  'United States',
#  'United States',
#  'Russia',
#  'Peru',
#  'Antarctica',
#  'Vanuatu',
#  'United States',
#  'Madagascar',
#  'Madagascar',
#  'Chile',
#  'New Zealand',
#  'Ecuador',
#  'Argentina',
#  'Argentina',
#  'Argentina',
#  'Chile',
#  'Vanuatu',
# ...

# %%
num = volcanos["Country"].value_counts()
dens = num / world["Land Area (Km2)"]
dens.dropna().sort_values(ascending=False).iloc[:20]
# Out:
# Tonga                  0.027778
# Montserrat             0.010000
# Wallis & Futuna        0.007143
# Dominica               0.006667
# American Samoa         0.005000
# Grenada                0.002941
# Vanuatu                0.001148
# Comoros                0.001075
# El Salvador            0.001062
# Sao Tome & Principe    0.001042
# Martinique             0.000943
# Samoa                  0.000707
# Guadeloupe             0.000592
# Iceland                0.000379
# Japan                  0.000304
# Guatemala              0.000205
# Taiwan                 0.000198
# Costa Rica             0.000196
# Armenia                0.000176
# Philippines            0.000164
# dtype: float64

# %%
num
# Out:
# Country
# United States      184
# Russia             169
# Indonesia          136
# Japan              111
# Chile               87
#                   ...
# Grenada              1
# American Samoa       1
# Rwanda               1
# Wallis & Futuna      1
# Germany              1
# Name: count, Length: 96, dtype: int64

# %%
img = plt.imread("world.jpg")
plt.imshow(img, extent=[-180, 180, -90, 90], aspect='auto')
plt.scatter(volcanos["Longitude"], volcanos["Latitude"], c=volcanos["Elev"], cmap='inferno')

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 from scipy.misc import imread
#
# ImportError: cannot import name 'imread' from 'scipy.misc' (/usr/lib/python3.12/site-packages/scipy/misc/__init__.py)
